# %%
import numpy as np
import pandas as pd
# %matplotlib
import matplotlib.pyplot as plt

from numpy.random import randint

from sklearn.ensemble import RandomForestClassifier as rfc
# Out:
# Using matplotlib backend: TkAgg

# %%
x = np.array([randint(1, 100, 1000), [1]*1000]).transpose()
y = (np.random.rand(1000) < (x[:, 0]/100.0)).astype(int)

# %%
clf = rfc(n_estimators = 100, min_samples_split = 30)
clf.fit(x, y)

test = np.array([range(1, 101), [1]*100]).transpose()
probs = clf.predict_proba(test)

a = pd.DataFrame({'x': x[:, 0], 'y':y})
b = a.groupby('x')['y'].mean()
c = np.array([b.index.values, b.values]).transpose()

# %%
fig = plt.figure(figsize=(8, 4))
ax = fig.add_subplot(1,1,1)
ax.plot(test[:, 0], probs[:, 1])
# ax.plot(c[:, 0], c[:, 1])

# %%
clf.predict_proba([20, 1])
# Out:
# array([[ 0.88609473,  0.11390527]])

# %%
# Out:
# array([[  1.00000000e+00,   0.00000000e+00],
#        [  2.00000000e+00,   0.00000000e+00],
#        [  3.00000000e+00,   1.11111111e-01],
#        [  4.00000000e+00,   1.53846154e-01],
#        [  5.00000000e+00,   0.00000000e+00],
#        [  6.00000000e+00,   0.00000000e+00],
#        [  7.00000000e+00,   2.00000000e-01],
#        [  8.00000000e+00,   8.33333333e-02],
#        [  9.00000000e+00,   2.30769231e-01],
#        [  1.00000000e+01,   2.50000000e-01],
#        [  1.10000000e+01,   0.00000000e+00],
#        [  1.20000000e+01,   8.33333333e-02],
#        [  1.30000000e+01,   7.14285714e-02],
#        [  1.40000000e+01,   1.50000000e-01],
#        [  1.50000000e+01,   1.42857143e-01],
#        [  1.60000000e+01,   8.33333333e-02],
#        [  1.70000000e+01,   0.00000000e+00],
#        [  1.80000000e+01,   1.42857143e-01],
#        [  1.90000000e+01,   1.25000000e-01],
#        [  2.00000000e+01,   2.00000000e-01],
#        [  2.10000000e+01,   0.00000000e+00],
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-77-176a9b3d3bf5> in <module>()
# ----> 1 b.values
#
# AttributeError: 'numpy.ndarray' object has no attribute 'values'
